# %%
import mysql.connector

cnx = mysql.connector.connect(user='mp-it', password='oiQWBpG1RW',
                              host='10.253.0.26',
                              database='almacenmpapel', 
                              ssl_disabled=True
                             )

# %%
cursor = cnx.cursor(dictionary=True)
query = """
SELECT idAdmision, idUsuario, fecha, idTercero, observaciones, estado, idCentro, idAlmacen, idTransporte, numBultos, idTransaccion, idUsuarioestado, fechaEstado, idTipoAdmision, tipoCierre, idUsuarioModificacion, fechaUltModificacion, bloqueoVentas, idPedidoEntradaClasificacion, idUsuarioFacturacion, fechaFacturacion, incidencia, importeTransporte, descripcion, prioridad, prioridadAuto, terminado, idUsuarioTerminado, fechaTerminado, bultosTransporte, integracionError, textoErrorIntegracion, desglose, fechaEntradaAuto, idUsuarioEntradaAuto, reserva
FROM almacenmpapel.Admision;

"""
cursor.execute(query)
results = cursor.fetchall()

# %%
len(results)
# Out:
# 10266

# %%
cursor.execute("SHOW TABLES")
tables = cursor.fetchall()
[table[0] for table in tables]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 3
#       1 cursor.execute("SHOW TABLES")
#       2 tables = cursor.fetchall()
# ----> 3 [table[0] for table in tables]
#
# Cell In[14], line 3, in <listcomp>(.0)
#       1 cursor.execute("SHOW TABLES")
#       2 tables = cursor.fetchall()
# ----> 3 [table[0] for table in tables]
#
# KeyError: 0

# %%
tables
# Out:
# [{'Tables_in_almacenmpapel': 'Admision'},
#  {'Tables_in_almacenmpapel': 'AdmisionDocumento'},
#  {'Tables_in_almacenmpapel': 'AdmisionDocumentoArticulo'},
#  {'Tables_in_almacenmpapel': 'AdmisionDocumentoArticuloNR'},
#  {'Tables_in_almacenmpapel': 'AdmisionDocumentoArticuloPedido'},
#  {'Tables_in_almacenmpapel': 'AdmisionDocumentoArticuloPreReloteo'},
#  {'Tables_in_almacenmpapel': 'AdmisionDocumentoArticuloReloteo'},
#  {'Tables_in_almacenmpapel': 'AdmisionDocumentoPedido'},
#  {'Tables_in_almacenmpapel': 'AdmisionLinea'},
#  {'Tables_in_almacenmpapel': 'AdmisionLineaDesglose'},
#  {'Tables_in_almacenmpapel': 'AdmisionLineaDocumento'},
#  {'Tables_in_almacenmpapel': 'AdmisionLineaReserva'},
#  {'Tables_in_almacenmpapel': 'AdmisionMovimiento'},
#  {'Tables_in_almacenmpapel': 'AdmisionPalet'},
#  {'Tables_in_almacenmpapel': 'AdmisionPedidoEntrada'},
#  {'Tables_in_almacenmpapel': 'AdmisionSeriado'},
#  {'Tables_in_almacenmpapel': 'AdmisionTipoPalet'},
# ...
